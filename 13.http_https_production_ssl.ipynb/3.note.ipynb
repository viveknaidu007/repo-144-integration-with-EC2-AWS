# %%
ubuntu@ip-172-31-32-165:~$ sudo apt update
Hit:1 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble InRelease
Hit:2 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble-updates InRelease                                                 
Hit:3 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble-backports InRelease                                               
Hit:4 https://deb.nodesource.com/node_16.x nodistro InRelease                                                                 
Hit:5 http://security.ubuntu.com/ubuntu noble-security InRelease                                       
Reading package lists... Done
Building dependency tree... Done
Reading state information... Done
49 packages can be upgraded. Run 'apt list --upgradable' to see them.
ubuntu@ip-172-31-32-165:~$ sudo apt install certbot python3-certbot-nginx
Reading package lists... Done
Building dependency tree... Done
Reading state information... Done
The following additional packages will be installed:
  nginx nginx-common python3-acme python3-certbot python3-configargparse python3-icu python3-josepy python3-parsedatetime python3-rfc3339
Suggested packages:
  python-certbot-doc python3-certbot-apache fcgiwrap nginx-doc ssl-cert python-acme-doc python-certbot-nginx-doc
The following NEW packages will be installed:
  certbot nginx nginx-common python3-acme python3-certbot python3-certbot-nginx python3-configargparse python3-icu python3-josepy python3-parsedatetime python3-rfc3339
0 upgraded, 11 newly installed, 0 to remove and 49 not upgraded.
Need to get 1648 kB of archives.
After this operation, 7295 kB of additional disk space will be used.
Do you want to continue? [Y/n] Y
Get:1 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble-updates/main amd64 nginx-common all 1.24.0-2ubuntu7.3 [31.2 kB]
Get:2 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble-updates/main amd64 nginx amd64 1.24.0-2ubuntu7.3 [520 kB]
Get:3 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 python3-josepy all 1.14.0-1 [22.1 kB]
Get:4 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 python3-rfc3339 all 1.1-4 [6744 B]
Get:5 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 python3-acme all 2.9.0-1 [48.5 kB]
Get:6 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 python3-configargparse all 1.7-1 [31.7 kB]
Get:7 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 python3-parsedatetime all 2.6-3 [32.8 kB]
Get:8 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 python3-certbot all 2.9.0-1 [267 kB]
Get:9 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 certbot all 2.9.0-1 [89.2 kB]
Get:10 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/universe amd64 python3-certbot-nginx all 2.9.0-1 [66.0 kB]
Get:11 http://ap-south-1.ec2.archive.ubuntu.com/ubuntu noble/main amd64 python3-icu amd64 2.12-1build2 [534 kB]
Fetched 1648 kB in 0s (46.5 MB/s)     
Preconfiguring packages ...
Selecting previously unselected package nginx-common.
(Reading database ... 105048 files and directories currently installed.)
Preparing to unpack .../00-nginx-common_1.24.0-2ubuntu7.3_all.deb ...
Unpacking nginx-common (1.24.0-2ubuntu7.3) ...
Selecting previously unselected package nginx.
Preparing to unpack .../01-nginx_1.24.0-2ubuntu7.3_amd64.deb ...
Unpacking nginx (1.24.0-2ubuntu7.3) ...
Selecting previously unselected package python3-josepy.
Preparing to unpack .../02-python3-josepy_1.14.0-1_all.deb ...
Unpacking python3-josepy (1.14.0-1) ...
Selecting previously unselected package python3-rfc3339.
Preparing to unpack .../03-python3-rfc3339_1.1-4_all.deb ...
Unpacking python3-rfc3339 (1.1-4) ...
Selecting previously unselected package python3-acme.
Preparing to unpack .../04-python3-acme_2.9.0-1_all.deb ...
Unpacking python3-acme (2.9.0-1) ...
Selecting previously unselected package python3-configargparse.
Preparing to unpack .../05-python3-configargparse_1.7-1_all.deb ...
Unpacking python3-configargparse (1.7-1) ...
Selecting previously unselected package python3-parsedatetime.
Preparing to unpack .../06-python3-parsedatetime_2.6-3_all.deb ...
Unpacking python3-parsedatetime (2.6-3) ...
Selecting previously unselected package python3-certbot.
Preparing to unpack .../07-python3-certbot_2.9.0-1_all.deb ...
Unpacking python3-certbot (2.9.0-1) ...
Selecting previously unselected package certbot.
Preparing to unpack .../08-certbot_2.9.0-1_all.deb ...
Unpacking certbot (2.9.0-1) ...
Selecting previously unselected package python3-certbot-nginx.
Preparing to unpack .../09-python3-certbot-nginx_2.9.0-1_all.deb ...
Unpacking python3-certbot-nginx (2.9.0-1) ...
Selecting previously unselected package python3-icu.
Preparing to unpack .../10-python3-icu_2.12-1build2_amd64.deb ...
Unpacking python3-icu (2.12-1build2) ...
Setting up python3-configargparse (1.7-1) ...
Setting up python3-parsedatetime (2.6-3) ...
Setting up python3-icu (2.12-1build2) ...
Setting up python3-josepy (1.14.0-1) ...
Setting up python3-rfc3339 (1.1-4) ...
Setting up python3-acme (2.9.0-1) ...
Setting up python3-certbot (2.9.0-1) ...
Setting up certbot (2.9.0-1) ...
Created symlink /etc/systemd/system/timers.target.wants/certbot.timer → /usr/lib/systemd/system/certbot.timer.
Setting up nginx (1.24.0-2ubuntu7.3) ...
Setting up python3-certbot-nginx (2.9.0-1) ...
Setting up nginx-common (1.24.0-2ubuntu7.3) ...
Created symlink /etc/systemd/system/multi-user.target.wants/nginx.service → /usr/lib/systemd/system/nginx.service.
Processing triggers for ufw (0.36.2-6) ...
Processing triggers for man-db (2.12.0-4build2) ...
Scanning processes...                                                                                                                                                              
Scanning candidates...                                                                                                                                                             
Scanning linux images...                                                                                                                                                           

Pending kernel upgrade!
Running kernel version:
  6.8.0-1024-aws
Diagnostics:
  The currently running kernel version is not the expected kernel version 6.8.0-1029-aws.

Restarting the system to load the new kernel will not be handled automatically, so you should consider rebooting.

Restarting services...

Service restarts being deferred:
 /etc/needrestart/restart.d/dbus.service
 systemctl restart networkd-dispatcher.service
 systemctl restart systemd-logind.service
 systemctl restart unattended-upgrades.service

No containers need to be restarted.

User sessions running outdated binaries:
 ubuntu @ session #1070: ssh-agent[57272]
 ubuntu @ user manager service: systemd[5928]

No VM guests are running outdated hypervisor (qemu) binaries on this host.
ubuntu@ip-172-31-32-165:~$ sudo certbot certonly --standalone -d api.adtip.in
Saving debug log to /var/log/letsencrypt/letsencrypt.log
Enter email address (used for urgent renewal and security notices)
 (Enter 'c' to cancel): admin@adtip.in

- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
Please read the Terms of Service at
https://letsencrypt.org/documents/LE-SA-v1.5-February-24-2025.pdf. You must
agree in order to register with the ACME server. Do you agree?
- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
(Y)es/(N)o: Y

- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
Would you be willing, once your first certificate is successfully issued, to
share your email address with the Electronic Frontier Foundation, a founding
partner of the Let's Encrypt project and the non-profit organization that
develops Certbot? We'd like to send you email about our work encrypting the web,
EFF news, campaigns, and ways to support digital freedom.
- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
(Y)es/(N)o: Y
Account registered.
Requesting a certificate for api.adtip.in

- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
Could not bind TCP port 80 because it is already in use by another process on
this system (such as a web server). Please stop the program in question and then
try again.
- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
(R)etry/(C)ancel:

# %% [markdown]
# The error you’re encountering during the Certbot process (`Could not bind TCP port 80 because it is already in use by another process`) occurs because Certbot’s `--standalone` mode needs to bind to port 80 to verify domain ownership, but another process on your EC2 instance (`ip-172-31-32-165`, with IP `3.6.15.198`) is already using that port. Since you’re setting up HTTPS for your Node.js backend to resolve the mixed content issue with your frontend (`https://adtip.in`), we need to address this port conflict and complete the certificate issuance. Let’s resolve this step-by-step.
#
# ---
#
# ### Why the Error is Happening
# - **Certbot’s `--standalone` Mode**:
#   - The `--standalone` mode spins up a temporary web server on port 80 to handle the HTTP-01 challenge from Let’s Encrypt, which verifies that you control the domain `api.adtip.in`.
#   - If another process (e.g., your Node.js backend, Nginx, or another web server) is already listening on port 80, Certbot cannot bind to that port, resulting in the error.
#
# - **What’s Using Port 80?**:
#   - From your `apt install` output, you installed `nginx` (as part of `python3-certbot-nginx`), and it’s likely running and listening on port 80 by default.
#   - Alternatively, your Node.js backend might be configured to listen on port 80, though your backend is currently running on port `7082` (based on prior messages).
#
# ---
#
# ### Solution: Free Up Port 80 for Certbot
#
# To resolve this, we need to identify and temporarily stop the process using port 80, allow Certbot to complete the certificate issuance, and then proceed with setting up HTTPS for your Node.js backend.
#
# #### 1. **Identify the Process Using Port 80**
# - Check which process is using port 80:
#   ```bash
#   sudo netstat -tuln | grep :80
#   ```
#   - You might see output like:
#     ```
#     tcp  0  0 0.0.0.0:80  0.0.0.0:*  LISTEN  1234/nginx
#     ```
#     This indicates Nginx (process ID 1234) is listening on port 80.
#   - Alternatively, use:
#     ```bash
#     sudo lsof -i :80
#     ```
#     - Example output:
#       ```
#       COMMAND  PID  USER   FD   TYPE  DEVICE  SIZE/OFF  NODE  NAME
#       nginx    1234 root   6u   IPv4  12345   0t0       TCP   *:http (LISTEN)
#       ```
#
# #### 2. **Stop the Process Using Port 80**
# - **If It’s Nginx** (most likely, since you just installed it):
#   - Stop the Nginx service:
#     ```bash
#     sudo systemctl stop nginx
#     ```
#   - Verify that Nginx is stopped and port 80 is free:
#     ```bash
#     sudo netstat -tuln | grep :80
#     ```
#     - If no output, port 80 is now free.
#
# - **If It’s Your Node.js App** (less likely, since your backend is on port `7082`):
#   - If your Node.js app is using port 80, find its process ID:
#     ```bash
#     sudo lsof -i :80
#     ```
#     - Example output:
#       ```
#       COMMAND  PID  USER   FD   TYPE  DEVICE  SIZE/OFF  NODE  NAME
#       node     5678 ubuntu  6u   IPv4  12345   0t0       TCP   *:http (LISTEN)
#       ```
#   - Stop the Node.js process:
#     ```bash
#     kill -9 5678  # Replace 5678 with the actual PID
#     ```
#   - Alternatively, if using PM2:
#     ```bash
#     pm2 stop your-app
#     ```
#
# #### 3. **Retry Certbot to Obtain the Certificate**
# - With port 80 now free, retry the Certbot command:
#   ```bash
#   sudo certbot certonly --standalone -d api.adtip.in
#   ```
# - If you already entered your email (`admin@adtip.in`) and agreed to the terms, Certbot will proceed directly to the certificate issuance.
# - If successful, you’ll see output like:
#   ```
#   Successfully received certificate.
#   Certificate is saved at: /etc/letsencrypt/live/api.adtip.in/fullchain.pem
#   Key is saved at: /etc/letsencrypt/live/api.adtip.in/privkey.pem
#   This certificate expires on [date].
#   ```
# - The certificate files will be saved in `/etc/letsencrypt/live/api.adtip.in/`.
#
# #### 4. **Restart the Process That Was Using Port 80 (If Needed)**
# - If you stopped Nginx, you can restart it:
#   ```bash
#   sudo systemctl start nginx
#   ```
#   - However, since your backend is a Node.js app and not using Nginx, you might not need Nginx running. You can disable it to avoid future conflicts:
#     ```bash
#     sudo systemctl stop nginx
#     sudo systemctl disable nginx
#     ```
# - If you stopped your Node.js app, restart it:
#   ```bash
#   pm2 start your-app  # If using PM2
#   ```
#
# #### 5. **Update Your Node.js Backend to Use HTTPS**
# - Modify your backend code to use the `https` module with the new certificate:
#   ```javascript
#   const https = require("https");
#   const fs = require("fs");
#   const app = require("./config/app.js");
#
#   const server = https.createServer({
#     cert: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/fullchain.pem"),
#     key: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/privkey.pem"),
#   }, app);
#
#   server.listen(process.env.SERVER_PORT, () => {
#     console.log(`HTTPS Server running on port: ${process.env.SERVER_PORT}`);
#   });
#   ```
# - Ensure `process.env.SERVER_PORT` is set to `7082` in your `.env` file (or change to `443` if you prefer the standard HTTPS port):
#   ```
#   SERVER_PORT=7082
#   ```
# - Restart your backend:
#   ```bash
#   pm2 restart your-app  # If using PM2
#   ```
#
# #### 6. **Update AWS Security Group for HTTPS**
# - Ensure your EC2 instance’s Security Group allows inbound HTTPS traffic:
#   ```
#   Type: Custom TCP
#   Protocol: TCP
#   Port Range: 7082
#   Source: 0.0.0.0/0 (or 89.116.133.221/32 for the frontend IP)
#   ```
#   - If you switched to port `443`:
#     ```
#     Type: HTTPS
#     Protocol: TCP
#     Port Range: 443
#     Source: 0.0.0.0/0
#     ```
#
# #### 7. **Update Frontend to Use HTTPS Backend**
# - Update the API base URL in your frontend’s `.env` file:
#   ```env
#   VITE_API_URL=https://api.adtip.in:7082
#   ```
#   Or, if using port `443`:
#   ```env
#   VITE_API_URL=https://api.adtip.in
#   ```
# - Redeploy the frontend to Hostinger’s `public_html` directory.
#
# #### 8. **Test the Setup**
# - Test the backend directly:
#   - Open `https://api.adtip.in:7082/api/list-premium-posts` in your browser or Postman. It should return the expected JSON response.
# - Test the frontend:
#   - Open `https://adtip.in` and check the Network tab to confirm the `/list-premium-posts` request succeeds with a `200 OK` status.
# - The `NS_ERROR_GENERATE_FAILURE` and `EPROTO` errors should now be resolved, and the site should load the updated "Adtip" content.
#
# #### 9. **Request Google Re-Indexing**
# - Request re-indexing in **Google Search Console** to ensure the updated "Adtip" site is indexed:
#   - Go to **URL Inspection** → Enter `https://www.adtip.in` → Click **Request Indexing**.
#
# #### 10. **Set Up Certificate Auto-Renewal**
# - Let’s Encrypt certificates expire every 90 days. Test auto-renewal:
#   ```bash
#   sudo certbot renew --dry-run
#   ```
# - If successful, set up a cron job to renew automatically:
#   ```bash
#   crontab -e
#   ```
#   Add:
#   ```
#   0 0 * * * /usr/bin/certbot renew --quiet
#   ```
#
# ---
#
# ### Additional Notes
# - **Why Nginx Was Installed**:
#   - The `apt install certbot python3-certbot-nginx` command installed Nginx as a dependency of `python3-certbot-nginx`. Since you’re using `--standalone` mode and a Node.js backend, you don’t need Nginx. You can safely disable it (as shown above) to avoid future port conflicts.
# - **Reboot for Kernel Update**:
#   - Your `apt install` output noted a pending kernel upgrade (`6.8.0-1024-aws` to `6.8.0-1029-aws`). While not related to Certbot, you should reboot your instance to apply the update:
#     ```bash
#     sudo reboot
#     ```
#   - After rebooting, recheck that your Node.js app is running (e.g., with `pm2 start your-app`).
#
# ---
#
# ### Immediate Action
# - **Step 1**: Stop Nginx (or any process using port 80):
#   ```bash
#   sudo systemctl stop nginx
#   ```
# - **Step 2**: Retry Certbot:
#   ```bash
#   sudo certbot certonly --standalone -d api.adtip.in
#   ```
# - **Step 3**: Update your Node.js backend to use HTTPS and restart it.
# - **Step 4**: Update the frontend to use the HTTPS backend URL and redeploy.
# - **Step 5**: Test the setup and request re-indexing in Google Search Console.
#
# This will resolve the port conflict, allow Certbot to issue the certificate, and enable HTTPS on your backend, fixing the mixed content issue permanently. Let me know if you need help with any step!

# %%
ubuntu@ip-172-31-32-165:~$ sudo netstat -tuln | grep :80
sudo: netstat: command not found
ubuntu@ip-172-31-32-165:~$

# %% [markdown]
# The error `sudo: netstat: command not found` indicates that the `netstat` command is not installed on your Ubuntu system (`ip-172-31-32-165`, with IP `3.6.15.198`). This is preventing you from identifying the process using port 80, which is causing the Certbot error (`Could not bind TCP port 80 because it is already in use`). Since you’re working on setting up HTTPS for your Node.js backend to resolve the mixed content issue with your frontend (`https://adtip.in`), we need to find the process using port 80 and free it up for Certbot. Let’s address this step-by-step.
#
# ---
#
# ### Why `netstat` is Not Found
# - On modern Ubuntu systems (like Ubuntu 24.04 "Noble Numbat," which your instance is running based on the `apt update` output showing `noble` repositories), the `netstat` command is part of the `net-tools` package, which is not installed by default.
# - Ubuntu now favors alternative tools like `ss` (part of the `iproute2` package, which is typically pre-installed) for network diagnostics.
#
# ---
#
# ### Solution: Identify the Process Using Port 80 and Free It Up
#
# #### 1. **Use `ss` to Check for Port 80**
# Since `netstat` isn’t available, use the `ss` command to identify the process listening on port 80:
# ```bash
# sudo ss -tuln | grep :80
# ```
# - Example output:
#   ```
#   tcp   LISTEN  0  128  0.0.0.0:80  0.0.0.0:*
#   ```
# - This indicates that a process is listening on port 80 (`0.0.0.0:80`).
#
# #### 2. **Find the Process ID (PID) Using `lsof`**
# To identify the specific process using port 80, use the `lsof` command (which should be pre-installed on Ubuntu):
# ```bash
# sudo lsof -i :80
# ```
# - Example output:
#   ```
#   COMMAND  PID  USER   FD   TYPE  DEVICE  SIZE/OFF  NODE  NAME
#   nginx    1234 root   6u   IPv4  12345   0t0       TCP   *:http (LISTEN)
#   ```
# - This shows that Nginx (PID 1234) is using port 80. Based on your previous `apt install certbot python3-certbot-nginx` command, it’s likely Nginx, as it was installed and started automatically.
#
# #### 3. **Stop the Process Using Port 80**
# - **If It’s Nginx** (most likely):
#   - Stop the Nginx service:
#     ```bash
#     sudo systemctl stop nginx
#     ```
#   - Verify that port 80 is now free:
#     ```bash
#     sudo ss -tuln | grep :80
#     ```
#     - If no output, port 80 is free.
#   - Since you’re using a Node.js backend and not Nginx, you can disable Nginx to prevent future conflicts:
#     ```bash
#     sudo systemctl disable nginx
#     ```
#
# - **If It’s Another Process** (e.g., your Node.js app):
#   - If `lsof` shows a different process (e.g., `node`), note the PID and stop it:
#     ```bash
#     sudo kill -9 <PID>  # Replace <PID> with the actual PID from lsof
#     ```
#   - If your Node.js app is managed by PM2:
#     ```bash
#     pm2 stop your-app
#     ```
#   - However, your backend is running on port `7082` (based on prior messages), so it’s unlikely to be the Node.js app causing the conflict.
#
# #### 4. **Retry Certbot to Obtain the Certificate**
# With port 80 now free, retry the Certbot command:
# ```bash
# sudo certbot certonly --standalone -d api.adtip.in
# ```
# - Since you’ve already entered your email (`admin@adtip.in`) and agreed to the terms, Certbot should proceed with the certificate issuance.
# - If successful, you’ll see:
#   ```
#   Successfully received certificate.
#   Certificate is saved at: /etc/letsencrypt/live/api.adtip.in/fullchain.pem
#   Key is saved at: /etc/letsencrypt/live/api.adtip.in/privkey.pem
#   ```
#
# #### 5. **Proceed with HTTPS Setup for Your Node.js Backend**
# Once the certificate is issued, continue with the remaining steps to set up HTTPS for your backend:
# - **Update Backend Code**:
#   ```javascript
#   const https = require("https");
#   const fs = require("fs");
#   const app = require("./config/app.js");
#
#   const server = https.createServer({
#     cert: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/fullchain.pem"),
#     key: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/privkey.pem"),
#   }, app);
#
#   server.listen(process.env.SERVER_PORT, () => {
#     console.log(`HTTPS Server running on port: ${process.env.SERVER_PORT}`);
#   });
#   ```
# - **Restart Backend**:
#   ```bash
#   pm2 restart your-app  # If using PM2
#   ```
# - **Update AWS Security Group**:
#   - Allow inbound traffic on port `7082` (or `443` if you switch to the standard HTTPS port):
#     ```
#     Type: Custom TCP
#     Protocol: TCP
#     Port Range: 7082
#     Source: 0.0.0.0/0
#     ```
# - **Update Frontend**:
#   - Update the API base URL in your frontend’s `.env` file:
#     ```env
#     VITE_API_URL=https://api.adtip.in:7082
#     ```
#   - Redeploy the frontend to Hostinger.
#
# #### 6. **Test and Re-Index**
# - Test `https://api.adtip.in:7082/api/list-premium-posts` to ensure it works.
# - Test `https://adtip.in` to confirm the frontend loads the updated "Adtip" content.
# - Request re-indexing in **Google Search Console** to update the search result title to "Adtip".
#
# ---
#
# ### Alternative: Install `net-tools` (Optional)
# If you prefer using `netstat` instead of `ss`, you can install the `net-tools` package:
# ```bash
# sudo apt install net-tools
# ```
# Then retry:
# ```bash
# sudo netstat -tuln | grep :80
# ```
# However, `ss` and `lsof` are sufficient and already available, so this step is optional.
#
# ---
#
# ### Immediate Action
# - **Step 1**: Identify the process using port 80:
#   ```bash
#   sudo ss -tuln | grep :80
#   sudo lsof -i :80
#   ```
# - **Step 2**: Stop Nginx (or the conflicting process):
#   ```bash
#   sudo systemctl stop nginx
#   sudo systemctl disable nginx
#   ```
# - **Step 3**: Retry Certbot:
#   ```bash
#   sudo certbot certonly --standalone -d api.adtip.in
#   ```
# - **Step 4**: Proceed with setting up HTTPS on your Node.js backend.
#
# This will resolve the port conflict and allow you to complete the HTTPS setup, fixing the mixed content issue and enabling Google to index the updated "Adtip" site. Let me know if you need further assistance!

# %%
my current :
require("dotenv").config();
const app = require("./config/app.js");
const cors = require("cors");
const server = require("http").createServer(app);
const moment = require("moment");
const updatedTime = moment().utcOffset(330).format("YYYY-MM-DD HH:mm:ss");

// Configure CORS to allow requests from the specific frontend origin with all methods
app.use(cors({
  origin: ['https://adtip.in', 'https://www.adtip.in'], // Allow both origins
  methods: '*', // Allow all HTTP methods
  allowedHeaders: ['Content-Type','Authorization'], // Allow the Content-Type header
  credentials: true,
}));

app.options("*", cors());

// Set up WebSocket server for Ludo
const WebSocket = require("ws");
const wss = new WebSocket.Server({ server });
const setupLudoWebSocket = require("./websocket/ludoWebSocket");
setupLudoWebSocket(wss);

// Agora WebSocket setup
const WebSocketServer = require("./websocket/agoraWebSocket");
const wssAgora = new WebSocketServer(server); // Agora WebSocket server
console.log("Agora WebSocket server initialized");

// Route setup
app.use("/api", require("./routes/api-routes").router);
app.use("/", require("./routes/route.js").router);
app.use("/", require("./routes/render.js"));

// Error handler
const {
  apiErrorHandler,
  unexpectedErrorHandler,
} = require("./config/error.js");
app.use(apiErrorHandler);
unexpectedErrorHandler();

// Cron jobs
const cron = require("node-cron");
const { checkPlanExpiry } = require("./scripts/checkPlanExpiry");
const { checkPendingTransactions } = require("./scripts/checkPendingTransactions");
const { checkContentCreatorPlanExpiry } = require("./scripts/checkContentCreatorPlanExpiry");

// Check plan expiry daily at midnight
cron.schedule("0 0 * * *", async () => {
  console.log("Running plan expiry check...Corn Job1");
  await checkPlanExpiry();
});

const { updateAgoraToken } = require("./scripts/generateAgoraToken");// After existing cron jobs
cron.schedule("0 */23 * * *", async () => {
  console.log("Running Agora token generation...");
  await generateAndStoreAgoraToken();
});

// Check content creator plan expiry daily at midnight (uncomment if needed)
/*
cron.schedule("0 0 * * *", async () => {
  console.log("Running content creator plan expiry check...Corn Job3");
  await checkContentCreatorPlanExpiry();
});
*/

// Check pending transactions every minute (uncomment if needed)
/*
cron.schedule("* * * * *", async () => {
  console.log("Running pending transactions checking every minute...Corn Job2");
  await checkPendingTransactions();
});
*/

// Start the server
server.listen(process.env.SERVER_PORT, () => {
  console.log("MOMENT UPDATED TIME.....", updatedTime);
  console.log(`Server started and running on port: ${process.env.SERVER_PORT}`);
});

/*
// creatd new token when ever server starts
updateAgoraToken().then(() => console.log("Initial Agora token updated"));
// Export wssAgora for use in other modules
module.exports = { wssAgora };

*/

how to update

# %%
To implement the permanent solution for transitioning your Node.js backend to HTTPS (resolving the mixed content issue with your frontend `https://adtip.in` and enabling Google to index the updated "Adtip" site), you need to update your current backend code to use the `https` module instead of `http`. You’ve already obtained an SSL certificate for `api.adtip.in` using Certbot, so let’s modify your code to enable HTTPS, ensure proper CORS configuration, and test the setup. Below is the updated code with detailed explanations.

---

### Updated Backend Code with HTTPS

Here’s the modified version of your `index.js` (or equivalent entry file) to enable HTTPS:

```javascript
require("dotenv").config();
const app = require("./config/app.js");
const cors = require("cors");
const https = require("https"); // Import https module
const fs = require("fs"); // Import fs

# %% [markdown]
# ubuntu@ip-172-31-32-165:~$ sudo lsof -i :80
# COMMAND    PID     USER   FD   TYPE   DEVICE SIZE/OFF NODE NAME
# nginx   293496     root    5u  IPv4 14093395      0t0  TCP *:http (LISTEN)
# nginx   293496     root    6u  IPv6 14093396      0t0  TCP *:http (LISTEN)
# nginx   293497 www-data    5u  IPv4 14093395      0t0  TCP *:http (LISTEN)
# nginx   293497 www-data    6u  IPv6 14093396      0t0  TCP *:http (LISTEN)
# nginx   293498 www-data    5u  IPv4 14093395      0t0  TCP *:http (LISTEN)
# nginx   293498 www-data    6u  IPv6 14093396      0t0  TCP *:http (LISTEN)
# ubuntu@ip-172-31-32-165:~$ sudo systemctl stop nginx
# ubuntu@ip-172-31-32-165:~$ sudo ss -tuln | grep :80
# ubuntu@ip-172-31-32-165:~$ sudo certbot certonly --standalone -d api.adtip.in
# Saving debug log to /var/log/letsencrypt/letsencrypt.log
# Requesting a certificate for api.adtip.in
#
# Successfully received certificate.
# Certificate is saved at: /etc/letsencrypt/live/api.adtip.in/fullchain.pem
# Key is saved at:         /etc/letsencrypt/live/api.adtip.in/privkey.pem
# This certificate expires on 2025-08-25.
# These files will be updated when the certificate renews.
# Certbot has set up a scheduled task to automatically renew this certificate in the background.
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# If you like Certbot, please consider supporting our work by:
#  * Donating to ISRG / Let's Encrypt:   https://letsencrypt.org/donate
#  * Donating to EFF:                    https://eff.org/donate-le
# - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# Great news! You’ve successfully obtained an SSL certificate for `api.adtip.in` using Certbot, with the certificate saved at `/etc/letsencrypt/live/api.adtip.in/`. The certificate is valid until August 25, 2025, and Certbot has set up an auto-renewal task. Now that port 80 is free (after stopping Nginx) and the certificate is issued, we can proceed with updating your Node.js backend to use HTTPS, ensuring compatibility with your frontend (`https://adtip.in`) and resolving the mixed content issue. This will also allow Google to index the updated "Adtip" site. Let’s update your backend code and complete the setup.
#
# ---
#
# ### Step 1: Update Your Node.js Backend Code to Use HTTPS
# You previously shared your backend code, which uses the `http` module to create the server. We need to replace this with the `https` module and load the SSL certificate and key files generated by Certbot. Below is the updated version of your backend code (e.g., `index.js` or your main server file):
#
# ```javascript
# require("dotenv").config();
# const app = require("./config/app.js");
# const cors = require("cors");
# const https = require("https"); // Replace http with https
# const fs = require("fs"); // Import fs to load certificate files
# const moment = require("moment");
# const updatedTime = moment().utcOffset(330).format("YYYY-MM-DD HH:mm:ss");
#
# // Configure CORS to allow requests from the specific frontend origin with all methods
# app.use(cors({
#   origin: ['https://adtip.in', 'https://www.adtip.in'], // Allow both origins
#   methods: '*', // Allow all HTTP methods
#   allowedHeaders: ['Content-Type', 'Authorization'], // Allow specified headers
#   credentials: true,
# }));
#
# app.options("*", cors());
#
# // Create HTTPS server with the SSL certificate and key
# const server = https.createServer({
#   cert: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/fullchain.pem"),
#   key: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/privkey.pem"),
# }, app);
#
# // Set up WebSocket server for Ludo
# const WebSocket = require("ws");
# const wss = new WebSocket.Server({ server });
# const setupLudoWebSocket = require("./websocket/ludoWebSocket");
# setupLudoWebSocket(wss);
#
# // Agora WebSocket setup
# const WebSocketServer = require("./websocket/agoraWebSocket");
# const wssAgora = new WebSocketServer(server); // Agora WebSocket server
# console.log("Agora WebSocket server initialized");
#
# // Route setup
# app.use("/api", require("./routes/api-routes").router);
# app.use("/", require("./routes/route.js").router);
# app.use("/", require("./routes/render.js"));
#
# // Error handler
# const {
#   apiErrorHandler,
#   unexpectedErrorHandler,
# } = require("./config/error.js");
# app.use(apiErrorHandler);
# unexpectedErrorHandler();
#
# // Cron jobs
# const cron = require("node-cron");
# const { checkPlanExpiry } = require("./scripts/checkPlanExpiry");
# const { checkPendingTransactions } = require("./scripts/checkPendingTransactions");
# const { checkContentCreatorPlanExpiry } = require("./scripts/checkContentCreatorPlanExpiry");
#
# // Check plan expiry daily at midnight
# cron.schedule("0 0 * * *", async () => {
#   console.log("Running plan expiry check...Corn Job1");
#   await checkPlanExpiry();
# });
#
# const { updateAgoraToken } = require("./scripts/generateAgoraToken");
# cron.schedule("0 */23 * * *", async () => {
#   console.log("Running Agora token generation...");
#   await updateAgoraToken(); // Fixed function name to match import
# });
#
# // Check content creator plan expiry daily at midnight (uncomment if needed)
# /*
# cron.schedule("0 0 * * *", async () => {
#   console.log("Running content creator plan expiry check...Corn Job3");
#   await checkContentCreatorPlanExpiry();
# });
# */
#
# // Check pending transactions every minute (uncomment if needed)
# /*
# cron.schedule("* * * * *", async () => {
#   console.log("Running pending transactions checking every minute...Corn Job2");
#   await checkPendingTransactions();
# });
# */
#
# // Start the server
# server.listen(process.env.SERVER_PORT, () => {
#   console.log("MOMENT UPDATED TIME.....", updatedTime);
#   console.log(`Server started and running on port: ${process.env.SERVER_PORT}`);
# });
#
# // Create new token whenever the server starts
# updateAgoraToken().then(() => console.log("Initial Agora token updated"));
#
# // Export wssAgora for use in other modules
# module.exports = { wssAgora };
# ```
#
# #### Changes Made:
# 1. **Replaced `http` with `https`**:
#    - Changed `const server = require("http").createServer(app)` to use the `https` module and load the SSL certificate and key:
#      ```javascript
#      const server = https.createServer({
#        cert: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/fullchain.pem"),
#        key: fs.readFileSync("/etc/letsencrypt/live/api.adtip.in/privkey.pem"),
#      }, app);
#      ```
#
# 2. **Fixed Agora Token Cron Job**:
#    - The cron job for Agora token generation was calling `generateAndStoreAgoraToken`, but the imported function is `updateAgoraToken`. Updated the cron job to:
#      ```javascript
#      await updateAgoraToken();
#      ```
#
# 3. **Uncommented Initial Agora Token Generation**:
#    - Uncommented the `updateAgoraToken()` call at server startup to ensure an initial Agora token is generated:
#      ```javascript
#      updateAgoraToken().then(() => console.log("Initial Agora token updated"));
#      ```
#
# 4. **Kept Other Functionality Intact**:
#    - Your WebSocket setups (Ludo and Agora), routes, error handlers, and cron jobs remain unchanged.
#
# ---
#
# ### Step 2: Ensure Port Configuration
# - Your backend is currently running on port `7082` (based on prior messages). Ensure this is set in your `.env` file:
#   ```
#   SERVER_PORT=7082
#   ```
# - If you prefer to use the standard HTTPS port (`443`), update the `.env` file:
#   ```
#   SERVER_PORT=443
#   ```
#   - Note: Using port `443` may require running the server with elevated privileges (`sudo`) or setting up port forwarding, as ports below 1024 are privileged on Linux.
#
# ---
#
# ### Step 3: Update AWS Security Group
# - Ensure your EC2 instance’s Security Group allows inbound HTTPS traffic on the port you’re using:
#   - If using port `7082`:
#     ```
#     Type: Custom TCP
#     Protocol: TCP
#     Port Range: 7082
#     Source: 0.0.0.0/0 (or 89.116.133.221/32 for the frontend IP)
#     ```
#   - If using port `443`:
#     ```
#     Type: HTTPS
#     Protocol: TCP
#     Port Range: 443
#     Source: 0.0.0.0/0
#     ```
#
# ---
#
# ### Step 4: Restart Your Backend
# - Restart your Node.js server to apply the HTTPS changes:
#   ```bash
#   pm2 restart your-app  # Replace "your-app" with your app’s name in PM2
#   ```
# - If you’re not using PM2, stop the current process and restart manually:
#   ```bash
#   node index.js  # Or your main file
#   ```
#
# ---
#
# ### Step 5: Update Frontend to Use HTTPS Backend
# - Update the API base URL in your frontend’s `.env` file to use the HTTPS backend:
#   ```env
#   VITE_API_URL=https://api.adtip.in:7082
#   ```
#   Or, if using port `443`:
#   ```env
#   VITE_API_URL=https://api.adtip.in
#   ```
# - Redeploy the frontend to Hostinger’s `public_html` directory:
#   - Upload the updated files via **hPanel** → **File Manager** or using SFTP/FTP.
#
# ---
#
# ### Step 6: Test the Setup
# - **Test the Backend Directly**:
#   - Open `https://api.adtip.in:7082/api/list-premium-posts` in your browser or Postman. It should return the expected JSON response:
#     ```json
#     {
#       "status": true,
#       "message": "Premium post lists",
#       "data": [...]
#     }
#     ```
# - **Test the Frontend**:
#   - Open `https://adtip.in` in your browser.
#   - Check the Network tab in the browser’s developer tools to confirm that the `/list-premium-posts` request succeeds with a `200 OK` status.
#   - The `NS_ERROR_GENERATE_FAILURE` and `EPROTO` errors should be resolved, and the site should load the updated "Adtip" content instead of "tip-tube-web".
#
# ---
#
# ### Step 7: Clear Caches
# - Clear your browser cache and test in incognito mode.
# - Flush your local DNS cache:
#   - **Windows**: `ipconfig /flushdns`
#   - **macOS**: `sudo dscacheutil -flushcache; sudo killall -HUP mDNSResponder`
# - Purge any CDN caches (e.g., Hostinger CDN or Cloudflare) via **hPanel** → **Advanced** → **CDN**.
#
# ---
#
# ### Step 8: Request Google Re-Indexing
# - Now that the frontend can fetch data from the backend over HTTPS, request re-indexing in **Google Search Console** to update the search result title to "Adtip":
#   - Go to **URL Inspection** → Enter `https://www.adtip.in` → Click **Request Indexing**.
# - Monitor the search result for "adtip" over the next few days to confirm the update.
#
# ---
#
# ### Additional Notes
# - **Auto-Renewal**: Certbot has already set up a scheduled task for certificate renewal (as noted in the output: "Certbot has set up a scheduled task to automatically renew this certificate in the background"). To verify, test the renewal:
#   ```bash
#   sudo certbot renew --dry-run
#   ```
#   - If successful, no further action is needed for renewal.
#
# - **Nginx**: Since you’re not using Nginx for your backend, you can leave it disabled to avoid future port conflicts:
#   ```bash
#   sudo systemctl stop nginx
#   sudo systemctl disable nginx
#   ```
#
# - **Reboot for Kernel Update**: Your earlier `apt install` output mentioned a pending kernel upgrade (`6.8.0-1024-aws` to `6.8.0-1029-aws`). Reboot your instance to apply the update:
#   ```bash
#   sudo reboot
#   ```
#   - After rebooting, restart your Node.js app:
#     ```bash
#     pm2 start your-app
#     ```
#
# ---
#
# ### Immediate Action
# - **Step 1**: Update your backend code with the HTTPS configuration (as shown above) and restart the server.
# - **Step 2**: Update the AWS Security Group to allow HTTPS traffic on port `7082` (or `443`).
# - **Step 3**: Update the frontend `.env` file with the HTTPS backend URL and redeploy.
# - **Step 4**: Test the backend and frontend to confirm the mixed content issue is resolved.
# - **Step 5**: Request re-indexing in Google Search Console.
#
# This completes the permanent HTTPS setup for your backend, resolving the `NS_ERROR_GENERATE_FAILURE` and `EPROTO` errors and ensuring Google indexes the updated "Adtip" site. Let me know if you encounter any issues during testing!
